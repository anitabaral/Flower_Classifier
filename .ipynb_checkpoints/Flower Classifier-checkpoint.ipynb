# %%
import pandas as pd
import numpy as np
import os, os.path
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import RMSprop, Adam
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping


num_classes = 17
img_size = 32 
batch_size = 8

train_data_dir = './17_flowers/train'
test_data_dir = './17_flowers/validation'

#To identify the number of files in the directory
# list = os.listdir(train_data_dir + '/daisy')
# num_files = len(list)
# print (num_files)

train_datagen = ImageDataGenerator(
    rescale = 1./255,
    rotation_range = 30,
    width_shift_range = 0.3,
    height_shift_range = 0.3,
    horizontal_flip = True,
    fill_mode = 'nearest')

validation_datagen = ImageDataGenerator(
    rescale = 1./255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_size,img_size),
    batch_size = batch_size,
    class_mode = 'categorical')

validation_generator = validation_datagen.flow_from_directory(
    test_data_dir,
    target_size = (img_size,img_size),
    batch_size = batch_size,
    class_mode = 'categorical')
# Out:
# Found 1190 images belonging to 17 classes.
# Found 170 images belonging to 17 classes.

# %% [markdown]
# ## Model from scratch

# %%
def create_model_from_scratch():
    
    model = Sequential()
    
    model.add(Conv2D(32, (3,3), padding = 'same', input_shape = (img_size, img_size, 3)))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    
    model.add(Conv2D(32, (3,3), padding = 'same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    
    model.add(MaxPooling2D(pool_size = (2, 2)))
#     model.add(Dropout(0.5))
    
    model.add(Conv2D(64, (3,3), padding = 'same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    
    model.add(Conv2D(64, (3,3), padding = 'same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    
    model.add(MaxPooling2D(pool_size = (2, 2)))
    model.add(Dropout(0.25))
    
    model.add(Conv2D(128, (3,3), padding = 'same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    
    model.add(Conv2D(128, (3,3), padding = 'same'))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
     
    model.add(MaxPooling2D(pool_size = (2, 2)))
    
       
#     model.add(Conv2D(256, (3,3), padding = 'same'))
#     model.add(Activation('relu'))
#     model.add(BatchNormalization())
    
#     model.add(Conv2D(256, (3,3), padding = 'same'))
#     model.add(Activation('relu'))
#     model.add(BatchNormalization())
     
#     model.add(MaxPooling2D(pool_size = (2, 2)))
#     model.add(Dropout(0.5)) 
    
    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))

    model.add(Dense(256))
    model.add(Activation('relu'))
    model.add(BatchNormalization())
    model.add(Dropout(0.25))

    model.add(Dense(num_classes))
    model.add(Activation("softmax"))
    
    print(model.summary())
    
    return model

# %%
scratch_model = create_model_from_scratch()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_97 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_139 (Activation)  (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_125 (Bat (None, 32, 32, 32)        128
# _________________________________________________________________
# conv2d_98 (Conv2D)           (None, 32, 32, 32)        9248
# _________________________________________________________________
# activation_140 (Activation)  (None, 32, 32, 32)        0
# _________________________________________________________________
# batch_normalization_126 (Bat (None, 32, 32, 32)        128
# _________________________________________________________________
# max_pooling2d_45 (MaxPooling (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_99 (Conv2D)           (None, 16, 16, 64)        18496
# _________________________________________________________________
# activation_141 (Activation)  (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_127 (Bat (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_100 (Conv2D)          (None, 16, 16, 64)        36928
# _________________________________________________________________
# activation_142 (Activation)  (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_128 (Bat (None, 16, 16, 64)        256
# _________________________________________________________________
# max_pooling2d_46 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# dropout_44 (Dropout)         (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_101 (Conv2D)          (None, 8, 8, 128)         73856
# _________________________________________________________________
# activation_143 (Activation)  (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_129 (Bat (None, 8, 8, 128)         512
# _________________________________________________________________
# conv2d_102 (Conv2D)          (None, 8, 8, 128)         147584
# _________________________________________________________________
# activation_144 (Activation)  (None, 8, 8, 128)         0
# _________________________________________________________________
# batch_normalization_130 (Bat (None, 8, 8, 128)         512
# _________________________________________________________________
# max_pooling2d_47 (MaxPooling (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_15 (Flatten)         (None, 2048)              0
# _________________________________________________________________
# dense_43 (Dense)             (None, 512)               1049088
# _________________________________________________________________
# activation_145 (Activation)  (None, 512)               0
# _________________________________________________________________
# batch_normalization_131 (Bat (None, 512)               2048
# _________________________________________________________________
# dropout_45 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_44 (Dense)             (None, 256)               131328
# _________________________________________________________________
# activation_146 (Activation)  (None, 256)               0
# _________________________________________________________________
# batch_normalization_132 (Bat (None, 256)               1024
# _________________________________________________________________
# dropout_46 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_45 (Dense)             (None, 17)                4369
# _________________________________________________________________
# activation_147 (Activation)  (None, 17)                0
# =================================================================
# Total params: 1,476,657
# Trainable params: 1,474,225
# Non-trainable params: 2,432
# _________________________________________________________________
# None

# %% [markdown]
# ## Training the model

# %%
nb_train_samples = 1190 
nb_validation_samples = 170 
epochs = 60

checkpoint = ModelCheckpoint("/home/deeplearningcv/Practice Projects/Flower Classifier/classified_flowers_vgg.h5",
                             monitor="val_loss",
                             mode="min",
                             save_best_only = True,
                             verbose=1)

earlystop = EarlyStopping(monitor = 'val_loss', 
                          min_delta = 0, 
                          patience = 3,
                          verbose = 1,
                          restore_best_weights = True)

reduce_lr = ReduceLROnPlateau(monitor = 'val_loss',
                              factor = 0.2,
                              patience = 3,
                              verbose = 1,
                              min_delta = 0.00001)

# we put our call backs into a callback list
callbacks = [earlystop, checkpoint, reduce_lr]

scratch_model.compile(loss = 'categorical_crossentropy',
             optimizer = Adam(lr = 0.001),
             metrics = ['accuracy'])

history = scratch_model.fit_generator(
    train_generator,
    steps_per_epoch = nb_train_samples // batch_size,
    epochs
60
# 148/148 [==============================] - 13s 86ms/step - loss: 1.5309 - accuracy: 0.5118 - val_loss: 1.5804 - val_accuracy: 0.5309
# Epoch 22/60
# 148/148 [==============================] - 13s 84ms/step - loss: 1.4486 - accuracy: 0.5372 - val_loss: 1.4593 - val_accuracy: 0.3951
# Epoch 23/60
# 148/148 [==============================] - 13s 86ms/step - loss: 1.4721 - accuracy: 0.5169 - val_loss: 3.1390 - val_accuracy: 0.5417
# Epoch 24/60
# 148/148 [==============================] - 13s 87ms/step - loss: 1.4192 - accuracy: 0.5236 - val_loss: 1.2205 - val_accuracy: 0.5802
# Epoch 25/60
# 148/148 [==============================] - 13s 87ms/step - loss: 1.3720 - accuracy: 0.5449 - val_loss: 1.2955 - val_accuracy: 0.4938
# Epoch 26/60
# 148/148 [==============================] - 13s 86ms/step - loss: 1.2612 - accuracy: 0.5694 - val_loss: 1.5464 - val_accuracy: 0.5309
# Epoch 27/60
# 148/148 [==============================] - 13s 89ms/step - loss: 1.3810 - accuracy: 0.5372 - val_loss: 0.8855 - val_accuracy: 0.5926
# Epoch 28/60
# 148/148 [==============================] - 13s 86ms/step - loss: 1.3161 - accuracy: 0.5635 - val_loss: 1.6936 - val_accuracy: 0.5679
# Epoch 29/60
# 148/148 [==============================] - 13s 86ms/step - loss: 1.2602 - accuracy: 0.5981 - val_loss: 0.6342 - val_accuracy: 0.5617
# Epoch 30/60
# 148/148 [==============================] - 13s 86ms/step - loss: 1.2758 - accuracy: 0.5567 - val_loss: 1.1385 - val_accuracy: 0.6111
# Epoch 31/60
# 148/148 [==============================] - 13s 85ms/step - loss: 1.2681 - accuracy: 0.5769 - val_loss: 1.0473 - val_accuracy: 0.5988
# Epoch 32/60
# 148/148 [==============================] - 13s 86ms/step - loss: 1.2211 - accuracy: 0.5890 - val_loss: 1.7122 - val_accuracy: 0.5432
# Epoch 33/60
# 148/148 [==============================] - 13s 86ms/step - loss: 1.2924 - accuracy: 0.5693 - val_loss: 0.7468 - val_accuracy: 0.5494
# Epoch 34/60
# 148/148 [==============================] - 13s 87ms/step - loss: 1.2177 - accuracy: 0.6178 - val_loss: 2.0442 - val_accuracy: 0.4753
# Epoch 35/60
# 148/148 [==============================] - 13s 86ms/step - loss: 1.2054 - accuracy: 0.5870 - val_loss: 1.2233 - val_accuracy: 0.5864
# Epoch 36/60
# 148/148 [==============================] - 13s 86ms/step - loss: 1.2024 - accuracy: 0.6000 - val_loss: 0.5369 - val_accuracy: 0.6605
# Epoch 37/60
# 148/148 [==============================] - 14s 92ms/step - loss: 1.2090 - accuracy: 0.5922 - val_loss: 0.4092 - val_accuracy: 0.6852
# Epoch 38/60
# 148/148 [==============================] - 26s 174ms/step - loss: 1.1869 - accuracy: 0.6100 - val_loss: 1.5868 - val_accuracy: 0.6852
# Epoch 39/60
# 148/148 [==============================] - 18s 124ms/step - loss: 1.1694 - accuracy: 0.6090 - val_loss: 1.0968 - val_accuracy: 0.6420
# Epoch 40/60
# 148/148 [==============================] - 16s 111ms/step - loss: 1.1711 - accuracy: 0.6144 - val_loss: 1.3413 - val_accuracy: 0.5926
# Epoch 41/60
# 148/148 [==============================] - 16s 110ms/step - loss: 1.0903 - accuracy: 0.6269 - val_loss: 0.9869 - val_accuracy: 0.5802
# Epoch 42/60
